# %%
using Images, FileIO
# Out:
# ┌ Info: Precompiling Images [916415d5-f1e6-5110-898d-aaa5f9f070e0]
# └ @ Base loading.jl:1278

# %%
# specify the path to your local image file
img_path = "ch04_cen98179_p04034_lg.png"
img = load(img_path)
# Out:
# 204×276 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱  ⋮
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
# ...

# %%
img |> size
# Out:
# (204, 276)

# %%
img2[100,:] .= colorant"red"
img2
# Out:
# 204×276 Array{RGBX{N0f8},2} with eltype RGBX{Normed{UInt8,8}}:
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)  …  RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)  …  RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)     RGBX{N0f8}(1.0,1.0,1.0)
#  RGBX{N0f8}(1.0,1.0,1.0)  RGBX{N0f8}(1.0,1.0,1.0)  …  RGBX{N0f8}(1.0,1.0,1.0)
# ...

# %%
img2=sym_paddedviews(colorant"red", img)
# Out:
# (RGBA{Normed{UInt8,8}}[RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0) … RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0); RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0) … RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0); … ; RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0) … RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0); RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0) … RGBA{N0f8}(1.0,1.0,1.0,1.0) RGBA{N0f8}(1.0,1.0,1.0,1.0)],)

# %%
image(img2)
# Out:
# UndefVarError: image not defined
#
# Stacktrace:
#  [1] top-level scope at In[38]:1

# %%
img[100,100] |> typeof
# Out:
# RGBA{Normed{UInt8,8}}

# %%
using Colors

# %%
colorant"transparent" |> typeof
# Out:
# RGBA{Normed{UInt8,8}}

# %%
colorview(RGB, img2)
# Out:
# MethodError: no method matching colorview(::Type{RGB}, ::Tuple{PaddedView{RGBA{Normed{UInt8,8}},2,Tuple{UnitRange{Int64},UnitRange{Int64}},Array{RGBA{Normed{UInt8,8}},2}}})
# Closest candidates are:
#   colorview(::Type{C}, ::Any, !Matched::Any, !Matched::Any...) where C<:Colorant at /Users/psydat/.julia/packages/ImageCore/ueJJz/src/colorchannels.jl:186
#   colorview(::Type{C}) where C<:Colorant at /Users/psydat/.julia/packages/ImageCore/ueJJz/src/colorchannels.jl:215
#   colorview(::Type{C}, !Matched::ImageMeta{T,N,A,P} where P<:AbstractDict{Symbol,Any} where A<:AbstractArray) where {C<:Colorant, T, N} at /Users/psydat/.julia/packages/ImageMetadata/gFA3T/src/ImageMetadata.jl:253
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[41]:1

# %%
Matrix(undef, 5, 5)
# Out:
# 5×5 Array{Any,2}:
#  #undef  #undef  #undef  #undef  #undef
#  #undef  #undef  #undef  #undef  #undef
#  #undef  #undef  #undef  #undef  #undef
#  #undef  #undef  #undef  #undef  #undef
#  #undef  #undef  #undef  #undef  #undef

# %%
Array(colorant"red", 5, 5)
# Out:
# MethodError: no method matching Array(::RGB{Normed{UInt8,8}}, ::Int64, ::Int64)
# Closest candidates are:
#   Array(!Matched::LinearAlgebra.UniformScaling, ::Integer, ::Integer) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/uniformscaling.jl:438
#
# Stacktrace:
#  [1] top-level scope at In[44]:1
